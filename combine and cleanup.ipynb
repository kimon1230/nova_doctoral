# %%
import pandas as pd
import json
import datetime
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
import shutil #to get shell info
import sys #system interaction

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kimon\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kimon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def clearLine():
    columns, _ = shutil.get_terminal_size(fallback=(80,20)) #get the terminal size retaining just the column count, ignoring the rows
    sys.stdout.write('\r' + ' ' * columns * 2 + '\r') #reset to the beginning of the line and print enough spaces to clear out the line. We're multiplying by 2 to cover the line
    sys.stdout.flush() #flush the buffer

def logMessage(msg: str):
    clearLine() #clear the whole line
    ts = datetime.datetime.now() #get the current timestamp
    print(f"\r{ts}\t{msg}",end='\r',flush=True) #print the message

# %%
def preprocess_text_no_sentences(text):
    """
    Preprocess a single review text.
    - Lowercasing
    - Removing URLs
    - Removing special characters and punctuation
    - Tokenizing sentences and words
    #- Removing stopwords
    - Re-joining words
    """
    # Convert to lowercase
    text = text.lower()
    
    # Remove URLs
    text = re.sub(r'http\S+|www.\S+', '', text)
    
    # Remove special characters and punctuation
    text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)
    
    # Tokenize sentences
    sentences = sent_tokenize(text)
    
    # Initialize NLTK's list of stopwords
    stop_words = set(stopwords.words('english'))
    
    # Process each sentence
    processed_sentences = []
    for sentence in sentences:
        # Tokenize words
        words = word_tokenize(sentence)
        # Remove stopwords and non-alphabetic words
        filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
        processed_sentences.append(' '.join(filtered_words))
    
    # Re-join sentences
    return ' '.join(processed_sentences)

# %%
def preprocess_text_sentences(text):
    """
    Preprocess text data at the sentence level.
    - Lowercasing
    - Removing URLs
    - Removing special characters and punctuation
    - Tokenizing sentences and words
    #- Removing stopwords
    - Keeping sentences separate
    """
    # Convert to lowercase
    text = text.lower()
    
    # Remove URLs
    text = re.sub(r'http\S+|www.\S+', '', text)
    
    # Tokenize into sentences
    sentences = sent_tokenize(text)
    
    ## Initialize NLTK's list of stopwords
    #stop_words = set(stopwords.words('english'))
    
    processed_sentences = []
    for sentence in sentences:
        # Remove special characters and punctuation
        sentence = re.sub(f'[{re.escape(string.punctuation)}]', '', sentence)
        
        # Tokenize words
        words = word_tokenize(sentence)
        
        # Remove stopwords and non-alphabetic words
        filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
        
        # Check if sentence is not empty after preprocessing
        if filtered_words:
            processed_sentences.append(' '.join(filtered_words))
    
    return processed_sentences

# %%
def remove_emojis(text):
    """
    Remove emojis from the text by targeting specific Unicode blocks.
    """
    # Unicode ranges for emojis
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251" 
        "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', text)

# %%
def rating_to_sentiment(rating, max_rating):
    rtg = float(rating)
    if max_rating == 5.0:
        match rtg:
            case rtg if 0.0 <= rtg < 2.5:
                return 'negative'
            case rtg if 2.5 <= rtg <= 3.5:
                return 'neutral'
            case rtg if 3.5 < rtg <= 5.0:
                return 'positive'
            case _:
                return 'error'
    if max_rating == 10.0:
        match rtg:
            case rtg if 0.0 <= rtg <= 4.0:
                return 'negative'
            case rtg if 4.0 < rtg < 6.0:
                return 'neutral'
            case rtg if 6.0 <= rtg <= 10.0:
                return 'positive'
            case _:
                return 'error'
    
    return 'error'

# %%
f1=r".\\trusted_pilot_car_dealerships-20240207.json"
f2=r".\\boardgamegeek-20240211.json"
dfTP = pd.read_json(f1)
dfBG = pd.read_json(f2)
dfTP['review_count'] = dfTP['reviews'].apply(lambda x: len(x))
dfBG['review_count'] = dfBG['reviews'].apply(lambda x: len(x))

tpProds = len(dfTP)
tpRevs = len(dfBG)

print(f"TrustPilot\tBusinesses: {tpProds}\tTotal reviews: {dfTP['review_count'].sum()}")
print(f"BoardGameGeek\tGames: {tpRevs}\tTotal reviews: {dfBG['review_count'].sum()}")
# Out:
# TrustPilot	Businesses: 93	Total reviews: 225020
# BoardGameGeek	Games: 250	Total reviews: 903916

# %%
tpProcessed = []
for index, row in dfTP.iterrows():
    nm = row['business_name']
    rc = row['review_count']
    rvs = row['reviews']
    rvws = []
    positives = 0
    neutrals = 0
    negatives = 0
    errors = 0

    print(f"Processing {nm} with {rc} reviews")
    for rv in rvs:
        rvttl = rv['review_title']
        rvtxt = rv['review_text']
        rvrtg = rv['rating']
        rvsent = rating_to_sentiment(rvrtg, 5.0)
        match rvsent:
            case 'negative':
                negatives += 1
            case 'neutral':
                neutrals += 1
            case 'positive':
                positives += 1
            case _:
                errors += 1
                rvsent = ''

        if not(rvtxt and len(rvtxt)>0):
            rvtxt = rvttl
        
        if rvtxt and len(rvtxt)>0:
            txt_no_sntc = preprocess_text_no_sentences(rvtxt)
            txt_no_sntc_no_emoji = remove_emojis(txt_no_sntc)
            txt_sntc = preprocess_text_sentences(rvtxt)
            txt_sntc_no_emoji= []
            for s in txt_sntc:
                sne = remove_emojis(s)
                txt_sntc_no_emoji.append(sne)
            rvws.append({'review_rating': rvrtg, 'review_title':rvttl, 'review_text_raw': rvtxt, 'review_sentiment': rvsent, 'review_text_preprocessed': txt_no_sntc, 'review_text_preprocessed_noemoji': txt_no_sntc_no_emoji, 'review_text_preprocessed_sentence': txt_sntc, 'review_text_preprocessed_sentence_noemoji': txt_sntc_no_emoji})
            logMessage(f"Processing {len(rvws)} of {rc}. Rating of {rvrtg} translated to {rvsent}")
        
    clearLine()
    tpProcessed.append({'name': nm, 'review_count':rc, 'negative_reviews': negatives, 'neutral_reviews': neutrals, 'positive_reviews': positives, 'reviews': rvws})
# Out:
# Processing Impex Auto Sales with 1 reviews
# Processing Beep Auto with 1 reviews
# Processing Len Lyall Chevrolet  with 1 reviews
# Processing Princeton Porsche with 1 reviews
# Processing CAS Auto LLC with 1 reviews
# Processing eCarsCash with 1 reviews
# Processing Cash For Cars - We Come To You LLC with 1 reviews
# Processing Kelly Nissan of Lynnfield with 1 reviews
# Processing Columbine Ford with 1 reviews
# Processing Auto Mart with 1 reviews
# Processing Southern Auto Mart with 1 reviews
# Processing JDM Export with 2 reviews
# Processing Kelly Honda with 1 reviews
# Processing We Buy All Cars in NJ with 2 reviews
# Processing Indy Auto Man Car Dealership with 2 reviews
# Processing RK Motors Charlotte with 2 reviews
# Processing CarSwitch with 3 reviews
# Processing Sunrise Chevrolet  with 3 reviews
# Processing BMW of Darien with 3 reviews
# Processing Waco Wholesale Trailers & Service Center with 3 reviews
# Processing Churchward car sales with 4 reviews
# Processing Cash For Cars with 4 reviews
# Processing TopDollarCar.com with 4 reviews
# Processing Kelly Ford with 5 reviews
# Processing Kelly Jeep Chrysler with 5 reviews
# Processing Roadra with 5 reviews
# Processing CertifiedCars.com with 5 reviews
# Processing The Deal Creator with 6 reviews
# Processing Public Motors with 7 reviews
# Processing Carable.com with 8 reviews
# Processing PushAuto with 8 reviews
# Processing RT 73 AutoMall with 9 reviews
# Processing GD Automotive with 9 reviews
# Processing Next Step Auto Sales with 8 reviews
# Processing PutInYourVIN.com with 10 reviews
# Processing Eurobahn BMW MINI Mercedes-Benz Audi  with 6 reviews
# Processing Robust Car Transport with 10 reviews
# Processing motorphilia.com with 12 reviews
# Processing Carfax Reports (Carsimulcast.com) with 13 reviews
# Processing FENTON FIRE with 16 reviews
# Processing J.D. Byrider - Cleveland, OH with 16 reviews
# Processing Kelly Volkswagen with 14 reviews
# Processing Maxxvin with 20 reviews
# Processing Redefined by VIP GROUP automotive with 23 reviews
# Processing savvicar.com with 23 reviews
# Processing Clutch with 26 reviews
# Processing ShipA1 Transport with 26 reviews
# Processing J.D. Byrider - Dorchester, MA with 34 reviews
# Processing Sunrise Motors Inc with 38 reviews
# Processing realtorgary.com with 32 reviews
# Processing Online Car Auctions with 43 reviews
# Processing MyHopscotch with 50 reviews
# Processing Enterprise Car Sales with 61 reviews
# Processing NowCar with 68 reviews
# Processing JD Cars  with 71 reviews
# Processing Holmlybiler with 3 reviews
# Processing Freedom Motors USA with 84 reviews
# Processing King of Clunkers with 86 reviews
# Processing Pierre Money Mart with 100 reviews
# Processing J.D. Byrider - Dartmouth, MA with 105 reviews
# Processing VehicleHistory.com with 132 reviews
# Processing Rollx Vans with 149 reviews
# Processing Wesley Chapel Honda with 188 reviews
# Processing Chesterfield Valley Investors with 206 reviews
# Processing Kraft Biler with 4 reviews
# Processing CarSoup.com with 305 reviews
# Processing DamagedCars.com with 311 reviews
# Processing Flexcar with 323 reviews
# Processing Superior Van and Mobility with 328 reviews
# Processing City Lending with 398 reviews
# Processing EchoPark Automotive with 430 reviews
# Processing gettacar with 451 reviews
# Processing Wesley Chapel Toyota with 483 reviews
# Processing Easterns Automotive Group with 843 reviews
# Processing ClassicCars.com with 1027 reviews
# Processing Tates with 1078 reviews
# Processing Oak Motors with 1191 reviews
# Processing Carstub with 1318 reviews
# Processing Driveway with 1334 reviews
# Processing Gullwing Motor with 1316 reviews
# Processing ALGO with 1774 reviews
# Processing WeBuyCars.com with 1937 reviews
# Processing Easy Auto with 1854 reviews
# Processing CashForCars.com with 2826 reviews
# Processing CarHop Auto Sales & Finance with 3004 reviews
# Processing J.D. Byrider with 3368 reviews
# Processing Auto Lenders with 3490 reviews
# Processing Shift with 4671 reviews
# Processing CarBrain with 5382 reviews
# Processing DriveTime Used Cars with 22962 reviews
# Processing Wheelzy with 43026 reviews
# Processing We Buy Any Car® USA with 46124 reviews
# Processing Peddle with 71678 reviews

# %%
print(len(tpProcessed))
# Out:
# 93

# %%
maxlen = 0
for r in tpProcessed:
    if len(r['name']) > maxlen:
        maxlen=len(r['name'])
        
for r in tpProcessed:
    spaces = ' ' * (maxlen - len(r['name']))
    print(f"name: {r['name']}{spaces}\treviews: {r['review_count']}\tnegatives: {r['negative_reviews']}\tneutrals: {r['neutral_reviews']}\tpositives: {r['positive_reviews']}")
# Out:
# name: Impex Auto Sales                        	reviews: 1	negatives: 1	neutrals: 0	positives: 0
# name: Beep Auto                               	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Len Lyall Chevrolet                     	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Princeton Porsche                       	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: CAS Auto LLC                            	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: eCarsCash                               	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Cash For Cars - We Come To You LLC      	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Kelly Nissan of Lynnfield               	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Columbine Ford                          	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Auto Mart                               	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: Southern Auto Mart                      	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: JDM Export                              	reviews: 2	negatives: 0	neutrals: 0	positives: 2
# name: Kelly Honda                             	reviews: 1	negatives: 0	neutrals: 0	positives: 1
# name: We Buy All Cars in NJ                   	reviews: 2	negatives: 1	neutrals: 0	positives: 1
# name: Indy Auto Man Car Dealership            	reviews: 2	negatives: 0	neutrals: 0	positives: 2
# name: RK Motors Charlotte                     	reviews: 2	negatives: 0	neutrals: 0	positives: 2
# name: CarSwitch                               	reviews: 3	negatives: 3	neutrals: 0	positives: 0
# name: Sunrise Chevrolet                       	reviews: 3	negatives: 1	neutrals: 1	positives: 1
# name: BMW of Darien                           	reviews: 3	negatives: 2	neutrals: 0	positives: 1
# name: Waco Wholesale Trailers & Service Center	reviews: 3	negatives: 2	neutrals: 0	positives: 1
# name: Churchward car sales                    	reviews: 4	negatives: 3	neutrals: 0	positives: 1
# name: Cash For Cars                           	reviews: 4	negatives: 0	neutrals: 0	positives: 4
# name: TopDollarCar.com                        	reviews: 4	negatives: 1	neutrals: 0	positives: 3
# name: Kelly Ford                              	reviews: 5	negatives: 2	neutrals: 0	positives: 3
# name: Kelly Jeep Chrysler                     	reviews: 5	negatives: 2	neutrals: 0	positives: 3
# name: Roadra                                  	reviews: 5	negatives: 0	neutrals: 0	positives: 5
# name: CertifiedCars.com                       	reviews: 5	negatives: 0	neutrals: 0	positives: 5
# name: The Deal Creator                        	reviews: 6	negatives: 0	neutrals: 0	positives: 6
# name: Public Motors                           	reviews: 7	negatives: 5	neutrals: 0	positives: 2
# name: Carable.com                             	reviews: 8	negatives: 2	neutrals: 0	positives: 6
# name: PushAuto                                	reviews: 8	negatives: 0	neutrals: 0	positives: 8
# name: RT 73 AutoMall                          	reviews: 9	negatives: 1	neutrals: 0	positives: 8
# name: GD Automotive                           	reviews: 9	negatives: 0	neutrals: 0	positives: 9
# name: Next Step Auto Sales                    	reviews: 8	negatives: 0	neutrals: 0	positives: 8
# name: PutInYourVIN.com                        	reviews: 10	negatives: 0	neutrals: 1	positives: 9
# name: Eurobahn BMW MINI Mercedes-Benz Audi    	reviews: 6	negatives: 0	neutrals: 1	positives: 5
# name: Robust Car Transport                    	reviews: 10	negatives: 0	neutrals: 0	positives: 10
# name: motorphilia.com                         	reviews: 12	negatives: 0	neutrals: 0	positives: 12
# name: Carfax Reports (Carsimulcast.com)       	reviews: 13	negatives: 0	neutrals: 0	positives: 13
# name: FENTON FIRE                             	reviews: 16	negatives: 2	neutrals: 0	positives: 14
# name: J.D. Byrider - Cleveland, OH            	reviews: 16	negatives: 2	neutrals: 1	positives: 13
# name: Kelly Volkswagen                        	reviews: 14	negatives: 1	neutrals: 1	positives: 12
# name: Maxxvin                                 	reviews: 20	negatives: 9	neutrals: 0	positives: 11
# name: Redefined by VIP GROUP automotive       	reviews: 23	negatives: 1	neutrals: 0	positives: 22
# name: savvicar.com                            	reviews: 23	negatives: 0	neutrals: 0	positives: 23
# name: Clutch                                  	reviews: 26	negatives: 4	neutrals: 0	positives: 22
# name: ShipA1 Transport                        	reviews: 26	negatives: 1	neutrals: 0	positives: 25
# name: J.D. Byrider - Dorchester, MA           	reviews: 34	negatives: 1	neutrals: 1	positives: 32
# name: Sunrise Motors Inc                      	reviews: 38	negatives: 13	neutrals: 0	positives: 25
# name: realtorgary.com                         	reviews: 32	negatives: 0	neutrals: 0	positives: 32
# name: Online Car Auctions                     	reviews: 43	negatives: 13	neutrals: 1	positives: 29
# name: MyHopscotch                             	reviews: 50	negatives: 7	neutrals: 2	positives: 41
# name: Enterprise Car Sales                    	reviews: 61	negatives: 37	neutrals: 1	positives: 23
# name: NowCar                                  	reviews: 68	negatives: 8	neutrals: 0	positives: 60
# name: JD Cars                                 	reviews: 71	negatives: 0	neutrals: 0	positives: 71
# name: Holmlybiler                             	reviews: 3	negatives: 0	neutrals: 0	positives: 3
# name: Freedom Motors USA                      	reviews: 84	negatives: 17	neutrals: 5	positives: 62
# name: King of Clunkers                        	reviews: 86	negatives: 2	neutrals: 1	positives: 83
# name: Pierre Money Mart                       	reviews: 100	negatives: 21	neutrals: 4	positives: 75
# name: J.D. Byrider - Dartmouth, MA            	reviews: 105	negatives: 3	neutrals: 0	positives: 102
# name: VehicleHistory.com                      	reviews: 132	negatives: 0	neutrals: 1	positives: 131
# name: Rollx Vans                              	reviews: 149	negatives: 5	neutrals: 5	positives: 139
# name: Wesley Chapel Honda                     	reviews: 188	negatives: 22	neutrals: 5	positives: 161
# name: Chesterfield Valley Investors           	reviews: 206	negatives: 71	neutrals: 13	positives: 122
# name: Kraft Biler                             	reviews: 4	negatives: 0	neutrals: 0	positives: 4
# name: CarSoup.com                             	reviews: 305	negatives: 37	neutrals: 27	positives: 241
# name: DamagedCars.com                         	reviews: 311	negatives: 9	neutrals: 5	positives: 297
# name: Flexcar                                 	reviews: 323	negatives: 79	neutrals: 35	positives: 209
# name: Superior Van and Mobility               	reviews: 328	negatives: 6	neutrals: 4	positives: 318
# name: City Lending                            	reviews: 398	negatives: 12	neutrals: 4	positives: 382
# name: EchoPark Automotive                     	reviews: 430	negatives: 159	neutrals: 21	positives: 250
# name: gettacar                                	reviews: 451	negatives: 17	neutrals: 16	positives: 418
# name: Wesley Chapel Toyota                    	reviews: 483	negatives: 22	neutrals: 0	positives: 461
# name: Easterns Automotive Group               	reviews: 843	negatives: 150	neutrals: 37	positives: 656
# name: ClassicCars.com                         	reviews: 1027	negatives: 98	neutrals: 50	positives: 879
# name: Tates                                   	reviews: 1078	negatives: 51	neutrals: 28	positives: 999
# name: Oak Motors                              	reviews: 1191	negatives: 194	neutrals: 70	positives: 927
# name: Carstub                                 	reviews: 1318	negatives: 23	neutrals: 9	positives: 1286
# name: Driveway                                	reviews: 1334	negatives: 631	neutrals: 38	positives: 665
# name: Gullwing Motor                          	reviews: 1316	negatives: 22	neutrals: 10	positives: 1284
# name: ALGO                                    	reviews: 1774	negatives: 100	neutrals: 41	positives: 1633
# name: WeBuyCars.com                           	reviews: 1937	negatives: 111	neutrals: 5	positives: 1821
# name: Easy Auto                               	reviews: 1854	negatives: 100	neutrals: 45	positives: 1709
# name: CashForCars.com                         	reviews: 2826	negatives: 234	neutrals: 119	positives: 2473
# name: CarHop Auto Sales & Finance             	reviews: 3004	negatives: 439	neutrals: 152	positives: 2413
# name: J.D. Byrider                            	reviews: 3368	negatives: 612	neutrals: 158	positives: 2598
# name: Auto Lenders                            	reviews: 3490	negatives: 89	neutrals: 50	positives: 3351
# name: Shift                                   	reviews: 4671	negatives: 909	neutrals: 198	positives: 3564
# name: CarBrain                                	reviews: 5382	negatives: 123	neutrals: 95	positives: 5164
# name: DriveTime Used Cars                     	reviews: 22962	negatives: 2569	neutrals: 685	positives: 19708
# name: Wheelzy                                 	reviews: 43026	negatives: 1451	neutrals: 833	positives: 40742
# name: We Buy Any Car® USA                     	reviews: 46124	negatives: 661	neutrals: 562	positives: 44901
# name: Peddle                                  	reviews: 71678	negatives: 4113	neutrals: 1734	positives: 65831

# %%
filename = f".\\trust_pilot_car_dealership_preprocessed-{datetime.datetime.now().strftime('%Y%m%d')}.json"
with open(filename, 'w', encoding='utf-8', newline='\n') as file:
    json.dump(tpProcessed, file, indent=4, ensure_ascii=False)

# %%
tpProcessed = []
dfTP = []

# %%
bggProcessed = []
for index, row in dfBG.iterrows():
    nm = row['game_name'][0]
    rc = row['review_count']
    rvs = row['reviews']
    rvws = []
    positives = 0
    neutrals = 0
    negatives = 0
    errors = 0

    print(f"Processing {nm} with {rc} reviews")
    for rv in rvs:
        rvttl = ''
        rvtxt = rv['review_text']
        rvrtg = rv['rating']
        rvsent = rating_to_sentiment(rvrtg, 10.0)
        match rvsent:
            case 'negative':
                negatives += 1
            case 'neutral':
                neutrals += 1
            case 'positive':
                positives += 1
            case _:
                errors += 1
                rvsent = ''
        
        if rvtxt and len(rvtxt)>0:
            txt_no_sntc = preprocess_text_no_sentences(rvtxt)
            txt_no_sntc_no_emoji = remove_emojis(txt_no_sntc)
            txt_sntc = preprocess_text_sentences(rvtxt)
            txt_sntc_no_emoji= []
            for s in txt_sntc:
                sne = remove_emojis(s)
                txt_sntc_no_emoji.append(sne)
            rvws.append({'review_rating': rvrtg, 'review_title':rvttl, 'review_text_raw': rvtxt, 'review_sentiment': rvsent, 'review_text_preprocessed': txt_no_sntc, 'review_text_preprocessed_noemoji': txt_no_sntc_no_emoji, 'review_text_preprocessed_sentence': txt_sntc, 'review_text_preprocessed_sentence_noemoji': txt_sntc_no_emoji})
            logMessage(f"Processing {len(rvws)} of {rc}. Rating of {rvrtg} translated to {rvsent}")
        
    clearLine()
    bggProcessed.append({'name': nm, 'review_count':rc, 'negative_reviews': negatives, 'neutral_reviews': neutrals, 'positive_reviews': positives, 'reviews': rvws})
# Out:
# Processing CATAN with 15659 reviews
# Processing Carcassonne with 15182 reviews
# Processing Pandemic with 13446 reviews
# Processing 7 Wonders with 11134 reviews
# Processing Terraforming Mars with 8799 reviews
# Processing 7 Wonders Duel with 7478 reviews
# Processing Dominion with 10895 reviews
# Processing Wingspan with 7750 reviews
# Processing Azul with 6650 reviews
# Processing Scythe with 7845 reviews
# Processing Splendor with 7248 reviews
# Processing Ticket to Ride: Europe with 7129 reviews
# Processing Small World with 7425 reviews
# Processing Puerto Rico with 9398 reviews
# Processing King of Tokyo with 7697 reviews
# Processing Love Letter with 7014 reviews
# Processing Power Grid with 8316 reviews
# Processing Patchwork with 4901 reviews
# Processing Dixit with 6243 reviews
# Processing Gloomhaven with 7231 reviews
# Processing The Castles of Burgundy with 6227 reviews
# Processing Race for the Galaxy with 8006 reviews
# Processing Lords of Waterdeep with 6406 reviews
# Processing Citadels with 7344 reviews
# Processing Pandemic Legacy: Season 1 with 5251 reviews
# Processing Stone Age with 6023 reviews
# Processing Everdell with 3976 reviews
# Processing Jaipur with 5018 reviews
# Processing Forbidden Island with 6401 reviews
# Processing Spirit Island with 4842 reviews
# Processing Munchkin with 6126 reviews
# Processing Root with 4212 reviews
# Processing Twilight Struggle with 6631 reviews
# Processing Hanabi with 4901 reviews
# Processing The Quacks of Quedlinburg with 3710 reviews
# Processing Viticulture Essential Edition with 3894 reviews
# Processing Terra Mystica with 4407 reviews
# Processing Kingdomino with 3816 reviews
# Processing Blood Rage with 4285 reviews
# Processing Sushi Go! with 4159 reviews
# Processing Dead of Winter: A Crossroads Game with 4267 reviews
# Processing Bohnanza with 6844 reviews
# Processing Coup with 5117 reviews
# Processing Lost Cities with 7452 reviews
# Processing Betrayal at House on the Hill with 6932 reviews
# Processing Star Realms with 4599 reviews
# Processing Takenoko with 3935 reviews
# Processing Brass: Birmingham with 3467 reviews
# Processing Mysterium with 3668 reviews
# Processing Robinson Crusoe: Adventures on the Cursed Island with 4114 reviews
# Processing Arkham Horror: The Card Game with 3977 reviews
# Processing Dune: Imperium with 3543 reviews
# Processing Lost Ruins of Arnak with 2955 reviews
# Processing Clank!: A Deck-Building Adventure with 3341 reviews
# Processing Five Tribes: The Djinns of Naqala with 3776 reviews
# Processing The Resistance with 4607 reviews
# Processing The Crew: The Quest for Planet Nine with 2932 reviews
# Processing Sagrada with 3157 reviews
# Processing Ark Nova with 3318 reviews
# Processing Concordia with 3893 reviews
# Processing Arkham Horror with 6732 reviews
# Processing Magic: The Gathering with 6190 reviews
# Processing Santorini with 3494 reviews
# Processing Hive with 4967 reviews
# Processing Battlestar Galactica: The Board Game with 5225 reviews
# Processing Eldritch Horror with 3653 reviews
# Processing Chess with 5547 reviews
# Processing Mansions of Madness: Second Edition with 2907 reviews
# Processing Monopoly with 5541 reviews
# Processing Sheriff of Nottingham with 3450 reviews
# Processing Risk with 5451 reviews
# Processing Cascadia with 2547 reviews
# Processing Caverna: The Cave Farmers with 3415 reviews
# Processing A Game of Thrones: The Board Game (Second Edition) with 3091 reviews
# Processing Sushi Go Party! with 2808 reviews
# Processing Galaxy Trucker with 4497 reviews
# Processing Dominion: Intrigue with 2953 reviews
# Processing Exploding Kittens with 3098 reviews
# Processing Alhambra with 4918 reviews
# Processing The Resistance: Avalon with 3027 reviews
# Processing Mage Knight Board Game with 4214 reviews
# Processing Machi Koro with 3554 reviews
# Processing Gloomhaven: Jaws of the Lion with 2771 reviews
# Processing Cosmic Encounter with 4601 reviews
# Processing Saboteur with 3244 reviews
# Processing Scrabble with 4569 reviews
# Processing Colt Express with 2655 reviews
# Processing Star Wars: Rebellion with 3021 reviews
# Processing Roll for the Galaxy with 3177 reviews
# Processing Le Havre with 3837 reviews
# Processing Through the Ages: A New Story of Civilization with 2674 reviews
# Processing Istanbul with 2693 reviews
# Processing Forbidden Desert with 3227 reviews
# Processing Orléans with 2550 reviews
# Processing The Mind with 2590 reviews
# Processing For Sale with 4804 reviews
# Processing Welcome To... with 2214 reviews
# Processing Android: Netrunner with 4060 reviews
# Processing Memoir '44 with 5369 reviews
# Processing Nemesis with 2676 reviews
# Processing Caylus with 4563 reviews
# Processing Take 5 with 3587 reviews
# Processing Tigris & Euphrates with 5017 reviews
# Processing UNO with 3289 reviews
# Processing Eclipse: New Dawn for the Galaxy with 3573 reviews
# Processing Architects of the West Kingdom with 2273 reviews
# Processing Cartographers with 1903 reviews
# Processing Tsuro with 3928 reviews
# Processing Cards Against Humanity with 4023 reviews
# Processing Secret Hitler with 2521 reviews
# Processing El Grande with 4081 reviews
# Processing Shadows over Camelot with 4660 reviews
# Processing T.I.M.E Stories with 2602 reviews
# Processing One Night Ultimate Werewolf with 2817 reviews
# Processing Smash Up with 2973 reviews
# Processing Blokus with 4201 reviews
# Processing Camel Up with 2504 reviews
# Processing No Thanks! with 3956 reviews
# Processing Gaia Project with 2148 reviews
# Processing Just One with 2137 reviews
# Processing Tokaido with 2723 reviews
# Processing Survive: Escape from Atlantis! with 3441 reviews
# Processing Castles of Mad King Ludwig with 2751 reviews
# Processing Elder Sign with 3251 reviews
# Processing Isle of Skye: From Chieftain to King with 2269 reviews
# Processing Suburbia with 2806 reviews
# Processing Century: Spice Road with 2373 reviews
# Processing Star Wars: X-Wing Miniatures Game with 2729 reviews
# Processing Ra with 4531 reviews
# Processing Seasons with 2481 reviews
# Processing The Voyages of Marco Polo with 2063 reviews
# Processing Brass: Lancashire with 3071 reviews
# Processing Star Wars: Imperial Assault with 2241 reviews
# Processing The Quest for El Dorado with 2172 reviews
# Processing PARKS with 2227 reviews
# Processing BANG! The Dice Game with 2868 reviews
# Processing Flash Point: Fire Rescue with 3016 reviews
# Processing The Lord of the Rings: The Card Game with 3214 reviews
# Processing RoboRally with 4412 reviews
# Processing That's Pretty Clever! with 1682 reviews
# Processing San Juan with 4368 reviews
# Processing Raiders of the North Sea with 2044 reviews
# Processing Photosynthesis with 2059 reviews
# Processing Kingdom Builder with 2871 reviews
# Processing Troyes with 2742 reviews
# Processing Village with 2186 reviews
# Processing Targi with 2123 reviews
# Processing Twilight Imperium: Fourth Edition with 2292 reviews
# Processing Keyflower with 2506 reviews
# Processing Skull with 2256 reviews
# Processing Marvel Champions: The Card Game with 1848 reviews
# Processing Alchemists with 2018 reviews
# Processing Codenames: Duet with 1874 reviews
# Processing Legendary: A Marvel Deck Building Game with 2879 reviews
# Processing Codenames: Pictures with 1805 reviews
# Processing Deception: Murder in Hong Kong with 2314 reviews
# Processing Chronicles of Crime with 2202 reviews
# Processing The 7th Continent with 2520 reviews
# Processing Carcassonne: Expansion 1 – Inns & Cathedrals with 3199 reviews
# Processing Modern Art with 3630 reviews
# Processing Onitama with 2214 reviews
# Processing Decrypto with 1631 reviews
# Processing Hey, That's My Fish! with 3840 reviews
# Processing Dice Forge with 1768 reviews
# Processing Cyclades with 2413 reviews
# Processing Guillotine with 3716 reviews
# Processing Res Arcana with 1818 reviews
# Processing Ghost Stories with 3175 reviews
# Processing Spyfall with 2142 reviews
# Processing Magic Maze with 1703 reviews
# Processing Sherlock Holmes Consulting Detective: The Thames Murders & Other Cases with 2189 reviews
# Processing Friday with 2624 reviews
# Processing Coloretto with 3467 reviews
# Processing Captain Sonar with 2141 reviews
# Processing Dominant Species with 3029 reviews
# Processing Rising Sun with 1995 reviews
# Processing Dixit: Odyssey with 1384 reviews
# Processing The Isle of Cats with 1798 reviews
# Processing War of the Ring: Second Edition with 2159 reviews
# Processing Clue with 3227 reviews
# Processing Tiny Epic Galaxies with 2028 reviews
# Processing Acquire with 4448 reviews
# Processing Arboretum with 2488 reviews
# Processing Roll Player with 1825 reviews
# Processing Grand Austria Hotel with 1888 reviews
# Processing Jamaica with 2619 reviews
# Processing Clans of Caledonia with 1725 reviews
# Processing Tikal with 3036 reviews
# Processing Aeon's End with 1700 reviews
# Processing Thurn and Taxis with 3112 reviews
# Processing Food Chain Magnate with 2155 reviews
# Processing CATAN: Cities & Knights with 3088 reviews
# Processing Qwirkle with 2488 reviews
# Processing Concept with 1793 reviews
# Processing Tapestry with 2068 reviews
# Processing Kingsburg with 3012 reviews
# Processing Inis with 2089 reviews
# Processing Disney Villainous: The Worst Takes it All with 1815 reviews
# Processing Teotihuacan: City of Gods with 1578 reviews
# Processing Formula D with 2354 reviews
# Processing Mice and Mystics with 2312 reviews
# Processing Catan: Seafarers with 2523 reviews
# Processing Through the Ages: A Story of Civilization with 2935 reviews
# Processing Twilight Imperium: Third Edition with 3404 reviews
# Processing Apples to Apples with 4336 reviews
# Processing Potion Explosion with 1520 reviews
# Processing Kemet with 2005 reviews
# Processing Legends of Andor with 1652 reviews
# Processing Underwater Cities with 1448 reviews
# Processing Tiny Towns with 1583 reviews
# Processing Zombicide with 1788 reviews
# Processing Harry Potter: Hogwarts Battle with 1999 reviews
# Processing Point Salad with 1429 reviews
# Processing Bärenpark with 1754 reviews
# Processing Spot it! with 1596 reviews
# Processing Space Base with 1790 reviews
# Processing Innovation with 3022 reviews
# Processing Zombie Dice with 2467 reviews
# Processing Heat: Pedal to the Metal with 1445 reviews
# Processing Rummikub with 1874 reviews
# Processing Anachrony with 1719 reviews
# Processing Can't Stop with 3099 reviews
# Processing It's a Wonderful World with 1391 reviews
# Processing Mr. Jack with 2534 reviews
# Processing Hanamikoji with 1649 reviews
# Processing Calico with 1488 reviews
# Processing Russian Railroads with 1647 reviews
# Processing Telestrations with 1856 reviews
# Processing The Pillars of the Earth with 2480 reviews
# Processing Fluxx with 3291 reviews
# Processing Pandemic: On the Brink with 2218 reviews
# Processing Hero Realms with 1432 reviews
# Processing Flamme Rouge with 1665 reviews
# Processing Trajan with 1956 reviews
# Processing Biblios with 2876 reviews
# Processing Crokinole with 2515 reviews
# Processing Battle Line with 3619 reviews
# Processing Carcassonne: Expansion 2 – Traders & Builders with 2475 reviews
# Processing Champions of Midgard with 1884 reviews
# Processing Port Royal with 1556 reviews
# Processing Codenames with 209 reviews
# Processing Ticket to Ride with 8200 reviews
# Processing Agricola with 6686 reviews
# Processing Great Western Trail with 484 reviews
# Processing Tzolk'in: The Mayan Calendar with 1430 reviews
# Processing BANG! with 3625 reviews
# Processing A Feast for Odin with 531 reviews
# Processing Descent: Journeys in the Dark (Second Edition) with 2494 reviews
# Processing Imperial Settlers with 1350 reviews
# Processing Incan Gold with 3140 reviews

# %%
print(len(bggProcessed))
# Out:
# 250

# %%
maxlen = 0
for r in bggProcessed:
    if len(r['name']) > maxlen:
        maxlen=len(r['name'])
        
for r in bggProcessed:
    spaces = ' ' * (maxlen - len(r['name']))
    print(f"name: {r['name']}{spaces}\treviews: {r['review_count']}\tnegatives: {r['negative_reviews']}\tneutrals: {r['neutral_reviews']}\tpositives: {r['positive_reviews']}")
# Out:
# name: CATAN                                                                 	reviews: 15659	negatives: 1204	neutrals: 1360	positives: 13095
# name: Carcassonne                                                           	reviews: 15182	negatives: 517	neutrals: 793	positives: 13872
# name: Pandemic                                                              	reviews: 13446	negatives: 557	neutrals: 660	positives: 12229
# name: 7 Wonders                                                             	reviews: 11134	negatives: 413	neutrals: 494	positives: 10227
# name: Terraforming Mars                                                     	reviews: 8799	negatives: 468	neutrals: 346	positives: 7985
# name: 7 Wonders Duel                                                        	reviews: 7478	negatives: 186	neutrals: 200	positives: 7092
# name: Dominion                                                              	reviews: 10895	negatives: 551	neutrals: 635	positives: 9709
# name: Wingspan                                                              	reviews: 7750	negatives: 376	neutrals: 328	positives: 7046
# name: Azul                                                                  	reviews: 6650	negatives: 131	neutrals: 197	positives: 6322
# name: Scythe                                                                	reviews: 7845	negatives: 421	neutrals: 377	positives: 7047
# name: Splendor                                                              	reviews: 7248	negatives: 321	neutrals: 449	positives: 6478
# name: Ticket to Ride: Europe                                                	reviews: 7129	negatives: 187	neutrals: 323	positives: 6619
# name: Small World                                                           	reviews: 7425	negatives: 373	neutrals: 508	positives: 6544
# name: Puerto Rico                                                           	reviews: 9398	negatives: 354	neutrals: 356	positives: 8688
# name: King of Tokyo                                                         	reviews: 7697	negatives: 384	neutrals: 519	positives: 6794
# name: Love Letter                                                           	reviews: 7014	negatives: 358	neutrals: 506	positives: 6150
# name: Power Grid                                                            	reviews: 8316	negatives: 325	neutrals: 345	positives: 7646
# name: Patchwork                                                             	reviews: 4901	negatives: 91	neutrals: 171	positives: 4639
# name: Dixit                                                                 	reviews: 6243	negatives: 306	neutrals: 384	positives: 5553
# name: Gloomhaven                                                            	reviews: 7231	negatives: 554	neutrals: 275	positives: 6402
# name: The Castles of Burgundy                                               	reviews: 6227	negatives: 166	neutrals: 213	positives: 5848
# name: Race for the Galaxy                                                   	reviews: 8006	negatives: 370	neutrals: 370	positives: 7266
# name: Lords of Waterdeep                                                    	reviews: 6406	negatives: 239	neutrals: 287	positives: 5880
# name: Citadels                                                              	reviews: 7344	negatives: 485	neutrals: 557	positives: 6302
# name: Pandemic Legacy: Season 1                                             	reviews: 5251	negatives: 315	neutrals: 128	positives: 4808
# name: Stone Age                                                             	reviews: 6023	negatives: 222	neutrals: 274	positives: 5527
# name: Everdell                                                              	reviews: 3976	negatives: 183	neutrals: 164	positives: 3629
# name: Jaipur                                                                	reviews: 5018	negatives: 87	neutrals: 198	positives: 4733
# name: Forbidden Island                                                      	reviews: 6401	negatives: 318	neutrals: 627	positives: 5456
# name: Spirit Island                                                         	reviews: 4842	negatives: 207	neutrals: 153	positives: 4482
# name: Munchkin                                                              	reviews: 6126	negatives: 2017	neutrals: 1127	positives: 2982
# name: Root                                                                  	reviews: 4212	negatives: 219	neutrals: 173	positives: 3820
# name: Twilight Struggle                                                     	reviews: 6631	negatives: 289	neutrals: 224	positives: 6118
# name: Hanabi                                                                	reviews: 4901	negatives: 333	neutrals: 401	positives: 4167
# name: The Quacks of Quedlinburg                                             	reviews: 3710	negatives: 154	neutrals: 157	positives: 3399
# name: Viticulture Essential Edition                                         	reviews: 3894	negatives: 150	neutrals: 155	positives: 3589
# name: Terra Mystica                                                         	reviews: 4407	negatives: 237	neutrals: 194	positives: 3976
# name: Kingdomino                                                            	reviews: 3816	negatives: 74	neutrals: 191	positives: 3551
# name: Blood Rage                                                            	reviews: 4285	negatives: 202	neutrals: 165	positives: 3918
# name: Sushi Go!                                                             	reviews: 4159	negatives: 144	neutrals: 280	positives: 3735
# name: Dead of Winter: A Crossroads Game                                     	reviews: 4267	negatives: 312	neutrals: 316	positives: 3639
# name: Bohnanza                                                              	reviews: 6844	negatives: 317	neutrals: 444	positives: 6083
# name: Coup                                                                  	reviews: 5117	negatives: 420	neutrals: 470	positives: 4227
# name: Lost Cities                                                           	reviews: 7452	negatives: 287	neutrals: 453	positives: 6712
# name: Betrayal at House on the Hill                                         	reviews: 6932	negatives: 814	neutrals: 650	positives: 5468
# name: Star Realms                                                           	reviews: 4599	negatives: 140	neutrals: 225	positives: 4234
# name: Takenoko                                                              	reviews: 3935	negatives: 166	neutrals: 279	positives: 3490
# name: Brass: Birmingham                                                     	reviews: 3467	negatives: 138	neutrals: 72	positives: 3257
# name: Mysterium                                                             	reviews: 3668	negatives: 236	neutrals: 240	positives: 3192
# name: Robinson Crusoe: Adventures on the Cursed Island                      	reviews: 4114	negatives: 225	neutrals: 205	positives: 3684
# name: Arkham Horror: The Card Game                                          	reviews: 3977	negatives: 243	neutrals: 186	positives: 3548
# name: Dune: Imperium                                                        	reviews: 3543	negatives: 148	neutrals: 103	positives: 3292
# name: Lost Ruins of Arnak                                                   	reviews: 2955	negatives: 123	neutrals: 150	positives: 2682
# name: Clank!: A Deck-Building Adventure                                     	reviews: 3341	negatives: 93	neutrals: 137	positives: 3111
# name: Five Tribes: The Djinns of Naqala                                     	reviews: 3776	negatives: 150	neutrals: 161	positives: 3465
# name: The Resistance                                                        	reviews: 4607	negatives: 295	neutrals: 338	positives: 3974
# name: The Crew: The Quest for Planet Nine                                   	reviews: 2932	negatives: 109	neutrals: 111	positives: 2712
# name: Sagrada                                                               	reviews: 3157	negatives: 119	neutrals: 154	positives: 2884
# name: Ark Nova                                                              	reviews: 3318	negatives: 198	neutrals: 132	positives: 2988
# name: Concordia                                                             	reviews: 3893	negatives: 72	neutrals: 108	positives: 3713
# name: Arkham Horror                                                         	reviews: 6732	negatives: 711	neutrals: 545	positives: 5476
# name: Magic: The Gathering                                                  	reviews: 6190	negatives: 546	neutrals: 398	positives: 5246
# name: Santorini                                                             	reviews: 3494	negatives: 117	neutrals: 179	positives: 3198
# name: Hive                                                                  	reviews: 4967	negatives: 155	neutrals: 304	positives: 4508
# name: Battlestar Galactica: The Board Game                                  	reviews: 5225	negatives: 374	neutrals: 299	positives: 4552
# name: Eldritch Horror                                                       	reviews: 3653	negatives: 254	neutrals: 193	positives: 3206
# name: Chess                                                                 	reviews: 5547	negatives: 567	neutrals: 592	positives: 4388
# name: Mansions of Madness: Second Edition                                   	reviews: 2907	negatives: 238	neutrals: 139	positives: 2530
# name: Monopoly                                                              	reviews: 5541	negatives: 3176	neutrals: 999	positives: 1366
# name: Sheriff of Nottingham                                                 	reviews: 3450	negatives: 247	neutrals: 277	positives: 2926
# name: Risk                                                                  	reviews: 5451	negatives: 1635	neutrals: 1272	positives: 2544
# name: Cascadia                                                              	reviews: 2547	negatives: 60	neutrals: 78	positives: 2409
# name: Caverna: The Cave Farmers                                             	reviews: 3415	negatives: 142	neutrals: 119	positives: 3154
# name: A Game of Thrones: The Board Game (Second Edition)                    	reviews: 3091	negatives: 243	neutrals: 155	positives: 2693
# name: Sushi Go Party!                                                       	reviews: 2808	negatives: 68	neutrals: 116	positives: 2624
# name: Galaxy Trucker                                                        	reviews: 4497	negatives: 311	neutrals: 252	positives: 3934
# name: Dominion: Intrigue                                                    	reviews: 2953	negatives: 111	neutrals: 123	positives: 2719
# name: Exploding Kittens                                                     	reviews: 3098	negatives: 886	neutrals: 543	positives: 1669
# name: Alhambra                                                              	reviews: 4918	negatives: 266	neutrals: 367	positives: 4285
# name: The Resistance: Avalon                                                	reviews: 3027	negatives: 193	neutrals: 153	positives: 2681
# name: Mage Knight Board Game                                                	reviews: 4214	negatives: 245	neutrals: 181	positives: 3788
# name: Machi Koro                                                            	reviews: 3554	negatives: 469	neutrals: 476	positives: 2609
# name: Gloomhaven: Jaws of the Lion                                          	reviews: 2771	negatives: 132	neutrals: 101	positives: 2538
# name: Cosmic Encounter                                                      	reviews: 4601	negatives: 376	neutrals: 285	positives: 3940
# name: Saboteur                                                              	reviews: 3244	negatives: 299	neutrals: 387	positives: 2558
# name: Scrabble                                                              	reviews: 4569	negatives: 710	neutrals: 757	positives: 3102
# name: Colt Express                                                          	reviews: 2655	negatives: 136	neutrals: 203	positives: 2316
# name: Star Wars: Rebellion                                                  	reviews: 3021	negatives: 103	neutrals: 72	positives: 2846
# name: Roll for the Galaxy                                                   	reviews: 3177	negatives: 150	neutrals: 178	positives: 2849
# name: Le Havre                                                              	reviews: 3837	negatives: 175	neutrals: 169	positives: 3493
# name: Through the Ages: A New Story of Civilization                         	reviews: 2674	negatives: 129	neutrals: 102	positives: 2443
# name: Istanbul                                                              	reviews: 2693	negatives: 85	neutrals: 114	positives: 2494
# name: Forbidden Desert                                                      	reviews: 3227	negatives: 132	neutrals: 207	positives: 2888
# name: Orléans                                                               	reviews: 2550	negatives: 71	neutrals: 86	positives: 2393
# name: The Mind                                                              	reviews: 2590	negatives: 371	neutrals: 239	positives: 1980
# name: For Sale                                                              	reviews: 4804	negatives: 103	neutrals: 204	positives: 4497
# name: Welcome To...                                                         	reviews: 2214	negatives: 57	neutrals: 103	positives: 2054
# name: Android: Netrunner                                                    	reviews: 4060	negatives: 187	neutrals: 171	positives: 3702
# name: Memoir '44                                                            	reviews: 5369	negatives: 222	neutrals: 289	positives: 4858
# name: Nemesis                                                               	reviews: 2676	negatives: 168	neutrals: 87	positives: 2421
# name: Caylus                                                                	reviews: 4563	negatives: 250	neutrals: 211	positives: 4102
# name: Take 5                                                                	reviews: 3587	negatives: 180	neutrals: 249	positives: 3158
# name: Tigris & Euphrates                                                    	reviews: 5017	negatives: 209	neutrals: 203	positives: 4605
# name: UNO                                                                   	reviews: 3289	negatives: 1120	neutrals: 866	positives: 1303
# name: Eclipse: New Dawn for the Galaxy                                      	reviews: 3573	negatives: 223	neutrals: 170	positives: 3180
# name: Architects of the West Kingdom                                        	reviews: 2273	negatives: 87	neutrals: 106	positives: 2080
# name: Cartographers                                                         	reviews: 1903	negatives: 37	neutrals: 70	positives: 1796
# name: Tsuro                                                                 	reviews: 3928	negatives: 347	neutrals: 518	positives: 3063
# name: Cards Against Humanity                                                	reviews: 4023	negatives: 1400	neutrals: 633	positives: 1990
# name: Secret Hitler                                                         	reviews: 2521	negatives: 201	neutrals: 151	positives: 2169
# name: El Grande                                                             	reviews: 4081	negatives: 133	neutrals: 165	positives: 3783
# name: Shadows over Camelot                                                  	reviews: 4660	negatives: 368	neutrals: 390	positives: 3902
# name: T.I.M.E Stories                                                       	reviews: 2602	negatives: 326	neutrals: 218	positives: 2058
# name: One Night Ultimate Werewolf                                           	reviews: 2817	negatives: 285	neutrals: 223	positives: 2309
# name: Smash Up                                                              	reviews: 2973	negatives: 354	neutrals: 397	positives: 2222
# name: Blokus                                                                	reviews: 4201	negatives: 154	neutrals: 325	positives: 3722
# name: Camel Up                                                              	reviews: 2504	negatives: 127	neutrals: 145	positives: 2232
# name: No Thanks!                                                            	reviews: 3956	negatives: 126	neutrals: 215	positives: 3615
# name: Gaia Project                                                          	reviews: 2148	negatives: 80	neutrals: 79	positives: 1989
# name: Just One                                                              	reviews: 2137	negatives: 49	neutrals: 63	positives: 2025
# name: Tokaido                                                               	reviews: 2723	negatives: 219	neutrals: 303	positives: 2201
# name: Survive: Escape from Atlantis!                                        	reviews: 3441	negatives: 82	neutrals: 159	positives: 3200
# name: Castles of Mad King Ludwig                                            	reviews: 2751	negatives: 87	neutrals: 116	positives: 2548
# name: Elder Sign                                                            	reviews: 3251	negatives: 295	neutrals: 332	positives: 2624
# name: Isle of Skye: From Chieftain to King                                  	reviews: 2269	negatives: 76	neutrals: 120	positives: 2073
# name: Suburbia                                                              	reviews: 2806	negatives: 120	neutrals: 148	positives: 2538
# name: Century: Spice Road                                                   	reviews: 2373	negatives: 137	neutrals: 167	positives: 2069
# name: Star Wars: X-Wing Miniatures Game                                     	reviews: 2729	negatives: 111	neutrals: 132	positives: 2486
# name: Ra                                                                    	reviews: 4531	negatives: 149	neutrals: 146	positives: 4236
# name: Seasons                                                               	reviews: 2481	negatives: 155	neutrals: 170	positives: 2156
# name: The Voyages of Marco Polo                                             	reviews: 2063	negatives: 73	neutrals: 95	positives: 1895
# name: Brass: Lancashire                                                     	reviews: 3071	negatives: 77	neutrals: 90	positives: 2904
# name: Star Wars: Imperial Assault                                           	reviews: 2241	negatives: 97	neutrals: 98	positives: 2046
# name: The Quest for El Dorado                                               	reviews: 2172	negatives: 43	neutrals: 58	positives: 2071
# name: PARKS                                                                 	reviews: 2227	negatives: 79	neutrals: 112	positives: 2036
# name: BANG! The Dice Game                                                   	reviews: 2868	negatives: 188	neutrals: 273	positives: 2407
# name: Flash Point: Fire Rescue                                              	reviews: 3016	negatives: 137	neutrals: 196	positives: 2683
# name: The Lord of the Rings: The Card Game                                  	reviews: 3214	negatives: 197	neutrals: 185	positives: 2832
# name: RoboRally                                                             	reviews: 4412	negatives: 400	neutrals: 308	positives: 3704
# name: That's Pretty Clever!                                                 	reviews: 1682	negatives: 58	neutrals: 72	positives: 1552
# name: San Juan                                                              	reviews: 4368	negatives: 125	neutrals: 259	positives: 3984
# name: Raiders of the North Sea                                              	reviews: 2044	negatives: 65	neutrals: 87	positives: 1892
# name: Photosynthesis                                                        	reviews: 2059	negatives: 144	neutrals: 194	positives: 1721
# name: Kingdom Builder                                                       	reviews: 2871	negatives: 238	neutrals: 271	positives: 2362
# name: Troyes                                                                	reviews: 2742	negatives: 127	neutrals: 108	positives: 2507
# name: Village                                                               	reviews: 2186	negatives: 71	neutrals: 145	positives: 1970
# name: Targi                                                                 	reviews: 2123	negatives: 60	neutrals: 94	positives: 1969
# name: Twilight Imperium: Fourth Edition                                     	reviews: 2292	negatives: 127	neutrals: 79	positives: 2086
# name: Keyflower                                                             	reviews: 2506	negatives: 95	neutrals: 92	positives: 2319
# name: Skull                                                                 	reviews: 2256	negatives: 124	neutrals: 157	positives: 1975
# name: Marvel Champions: The Card Game                                       	reviews: 1848	negatives: 77	neutrals: 80	positives: 1691
# name: Alchemists                                                            	reviews: 2018	negatives: 145	neutrals: 115	positives: 1758
# name: Codenames: Duet                                                       	reviews: 1874	negatives: 52	neutrals: 78	positives: 1744
# name: Legendary: A Marvel Deck Building Game                                	reviews: 2879	negatives: 165	neutrals: 177	positives: 2537
# name: Codenames: Pictures                                                   	reviews: 1805	negatives: 72	neutrals: 132	positives: 1601
# name: Deception: Murder in Hong Kong                                        	reviews: 2314	negatives: 113	neutrals: 141	positives: 2060
# name: Chronicles of Crime                                                   	reviews: 2202	negatives: 114	neutrals: 129	positives: 1959
# name: The 7th Continent                                                     	reviews: 2520	negatives: 214	neutrals: 174	positives: 2132
# name: Carcassonne: Expansion 1 – Inns & Cathedrals                          	reviews: 3199	negatives: 46	neutrals: 98	positives: 3055
# name: Modern Art                                                            	reviews: 3630	negatives: 129	neutrals: 154	positives: 3347
# name: Onitama                                                               	reviews: 2214	negatives: 94	neutrals: 127	positives: 1993
# name: Decrypto                                                              	reviews: 1631	negatives: 51	neutrals: 48	positives: 1532
# name: Hey, That's My Fish!                                                  	reviews: 3840	negatives: 116	neutrals: 291	positives: 3433
# name: Dice Forge                                                            	reviews: 1768	negatives: 87	neutrals: 128	positives: 1553
# name: Cyclades                                                              	reviews: 2413	negatives: 101	neutrals: 124	positives: 2188
# name: Guillotine                                                            	reviews: 3716	negatives: 314	neutrals: 508	positives: 2894
# name: Res Arcana                                                            	reviews: 1818	negatives: 82	neutrals: 116	positives: 1620
# name: Ghost Stories                                                         	reviews: 3175	negatives: 212	neutrals: 211	positives: 2752
# name: Spyfall                                                               	reviews: 2142	negatives: 199	neutrals: 210	positives: 1733
# name: Magic Maze                                                            	reviews: 1703	negatives: 131	neutrals: 142	positives: 1430
# name: Sherlock Holmes Consulting Detective: The Thames Murders & Other Cases	reviews: 2189	negatives: 115	neutrals: 103	positives: 1971
# name: Friday                                                                	reviews: 2624	negatives: 109	neutrals: 177	positives: 2338
# name: Coloretto                                                             	reviews: 3467	negatives: 99	neutrals: 224	positives: 3144
# name: Captain Sonar                                                         	reviews: 2141	negatives: 94	neutrals: 122	positives: 1925
# name: Dominant Species                                                      	reviews: 3029	negatives: 179	neutrals: 157	positives: 2693
# name: Rising Sun                                                            	reviews: 1995	negatives: 164	neutrals: 111	positives: 1720
# name: Dixit: Odyssey                                                        	reviews: 1384	negatives: 41	neutrals: 73	positives: 1270
# name: The Isle of Cats                                                      	reviews: 1798	negatives: 55	neutrals: 87	positives: 1656
# name: War of the Ring: Second Edition                                       	reviews: 2159	negatives: 52	neutrals: 33	positives: 2074
# name: Clue                                                                  	reviews: 3227	negatives: 779	neutrals: 821	positives: 1627
# name: Tiny Epic Galaxies                                                    	reviews: 2028	negatives: 104	neutrals: 122	positives: 1802
# name: Acquire                                                               	reviews: 4448	negatives: 156	neutrals: 244	positives: 4048
# name: Arboretum                                                             	reviews: 2488	negatives: 95	neutrals: 135	positives: 2258
# name: Roll Player                                                           	reviews: 1825	negatives: 75	neutrals: 99	positives: 1651
# name: Grand Austria Hotel                                                   	reviews: 1888	negatives: 84	neutrals: 70	positives: 1734
# name: Jamaica                                                               	reviews: 2619	negatives: 157	neutrals: 206	positives: 2256
# name: Clans of Caledonia                                                    	reviews: 1725	negatives: 44	neutrals: 51	positives: 1630
# name: Tikal                                                                 	reviews: 3036	negatives: 81	neutrals: 158	positives: 2797
# name: Aeon's End                                                            	reviews: 1700	negatives: 44	neutrals: 86	positives: 1570
# name: Thurn and Taxis                                                       	reviews: 3112	negatives: 148	neutrals: 228	positives: 2736
# name: Food Chain Magnate                                                    	reviews: 2155	negatives: 164	neutrals: 78	positives: 1913
# name: CATAN: Cities & Knights                                               	reviews: 3088	negatives: 259	neutrals: 243	positives: 2586
# name: Qwirkle                                                               	reviews: 2488	negatives: 159	neutrals: 270	positives: 2059
# name: Concept                                                               	reviews: 1793	negatives: 140	neutrals: 175	positives: 1478
# name: Tapestry                                                              	reviews: 2068	negatives: 291	neutrals: 151	positives: 1626
# name: Kingsburg                                                             	reviews: 3012	negatives: 151	neutrals: 261	positives: 2600
# name: Inis                                                                  	reviews: 2089	negatives: 110	neutrals: 93	positives: 1886
# name: Disney Villainous: The Worst Takes it All                             	reviews: 1815	negatives: 206	neutrals: 187	positives: 1422
# name: Teotihuacan: City of Gods                                             	reviews: 1578	negatives: 86	neutrals: 80	positives: 1412
# name: Formula D                                                             	reviews: 2354	negatives: 164	neutrals: 213	positives: 1977
# name: Mice and Mystics                                                      	reviews: 2312	negatives: 169	neutrals: 200	positives: 1943
# name: Catan: Seafarers                                                      	reviews: 2523	negatives: 156	neutrals: 214	positives: 2153
# name: Through the Ages: A Story of Civilization                             	reviews: 2935	negatives: 195	neutrals: 139	positives: 2601
# name: Twilight Imperium: Third Edition                                      	reviews: 3404	negatives: 269	neutrals: 184	positives: 2951
# name: Apples to Apples                                                      	reviews: 4336	negatives: 962	neutrals: 851	positives: 2523
# name: Potion Explosion                                                      	reviews: 1520	negatives: 72	neutrals: 128	positives: 1320
# name: Kemet                                                                 	reviews: 2005	negatives: 85	neutrals: 69	positives: 1851
# name: Legends of Andor                                                      	reviews: 1652	negatives: 131	neutrals: 167	positives: 1354
# name: Underwater Cities                                                     	reviews: 1448	negatives: 45	neutrals: 51	positives: 1352
# name: Tiny Towns                                                            	reviews: 1583	negatives: 95	neutrals: 108	positives: 1380
# name: Zombicide                                                             	reviews: 1788	negatives: 165	neutrals: 133	positives: 1490
# name: Harry Potter: Hogwarts Battle                                         	reviews: 1999	negatives: 113	neutrals: 118	positives: 1768
# name: Point Salad                                                           	reviews: 1429	negatives: 50	neutrals: 103	positives: 1276
# name: Bärenpark                                                             	reviews: 1754	negatives: 42	neutrals: 95	positives: 1617
# name: Spot it!                                                              	reviews: 1596	negatives: 113	neutrals: 222	positives: 1261
# name: Space Base                                                            	reviews: 1790	negatives: 109	neutrals: 116	positives: 1565
# name: Innovation                                                            	reviews: 3022	negatives: 283	neutrals: 212	positives: 2527
# name: Zombie Dice                                                           	reviews: 2467	negatives: 340	neutrals: 432	positives: 1695
# name: Heat: Pedal to the Metal                                              	reviews: 1445	negatives: 59	neutrals: 64	positives: 1322
# name: Rummikub                                                              	reviews: 1874	negatives: 230	neutrals: 323	positives: 1321
# name: Anachrony                                                             	reviews: 1719	negatives: 75	neutrals: 69	positives: 1575
# name: Can't Stop                                                            	reviews: 3099	negatives: 143	neutrals: 245	positives: 2711
# name: It's a Wonderful World                                                	reviews: 1391	negatives: 64	neutrals: 61	positives: 1266
# name: Mr. Jack                                                              	reviews: 2534	negatives: 121	neutrals: 174	positives: 2239
# name: Hanamikoji                                                            	reviews: 1649	negatives: 48	neutrals: 64	positives: 1537
# name: Calico                                                                	reviews: 1488	negatives: 65	neutrals: 81	positives: 1342
# name: Russian Railroads                                                     	reviews: 1647	negatives: 93	neutrals: 103	positives: 1451
# name: Telestrations                                                         	reviews: 1856	negatives: 69	neutrals: 97	positives: 1690
# name: The Pillars of the Earth                                              	reviews: 2480	negatives: 130	neutrals: 169	positives: 2181
# name: Fluxx                                                                 	reviews: 3291	negatives: 1130	neutrals: 620	positives: 1541
# name: Pandemic: On the Brink                                                	reviews: 2218	negatives: 16	neutrals: 41	positives: 2161
# name: Hero Realms                                                           	reviews: 1432	negatives: 55	neutrals: 84	positives: 1293
# name: Flamme Rouge                                                          	reviews: 1665	negatives: 71	neutrals: 83	positives: 1511
# name: Trajan                                                                	reviews: 1956	negatives: 114	neutrals: 92	positives: 1750
# name: Biblios                                                               	reviews: 2876	negatives: 98	neutrals: 151	positives: 2627
# name: Crokinole                                                             	reviews: 2515	negatives: 72	neutrals: 71	positives: 2372
# name: Battle Line                                                           	reviews: 3619	negatives: 73	neutrals: 142	positives: 3404
# name: Carcassonne: Expansion 2 – Traders & Builders                         	reviews: 2475	negatives: 60	neutrals: 104	positives: 2311
# name: Champions of Midgard                                                  	reviews: 1884	negatives: 56	neutrals: 74	positives: 1754
# name: Port Royal                                                            	reviews: 1556	negatives: 55	neutrals: 99	positives: 1402
# name: Codenames                                                             	reviews: 209	negatives: 9	neutrals: 4	positives: 196
# name: Ticket to Ride                                                        	reviews: 8200	negatives: 323	neutrals: 416	positives: 7461
# name: Agricola                                                              	reviews: 6686	negatives: 370	neutrals: 286	positives: 6030
# name: Great Western Trail                                                   	reviews: 484	negatives: 18	neutrals: 15	positives: 451
# name: Tzolk'in: The Mayan Calendar                                          	reviews: 1430	negatives: 53	neutrals: 42	positives: 1335
# name: BANG!                                                                 	reviews: 3625	negatives: 515	neutrals: 510	positives: 2600
# name: A Feast for Odin                                                      	reviews: 531	negatives: 17	neutrals: 20	positives: 494
# name: Descent: Journeys in the Dark (Second Edition)                        	reviews: 2494	negatives: 151	neutrals: 160	positives: 2183
# name: Imperial Settlers                                                     	reviews: 1350	negatives: 86	neutrals: 100	positives: 1164
# name: Incan Gold                                                            	reviews: 3140	negatives: 107	neutrals: 252	positives: 2781

# %%
filename = f".\\boardgamegeek_preprocessed-{datetime.datetime.now().strftime('%Y%m%d')}.json"
with open(filename, 'w', encoding='utf-8', newline='\n') as file:
    json.dump(bggProcessed, file, indent=4, ensure_ascii=False)

# %%
bggProcessed = []
dfBG = []
